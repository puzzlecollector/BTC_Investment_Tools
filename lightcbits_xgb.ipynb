# %%
# !pip install seaborn 
# !pip install ccxt 
# !pip install tabpfn 
# !pip install pandas-ta 
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.22.4)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ccxt in /usr/local/lib/python3.10/dist-packages (3.1.15)
# Requirement already satisfied: setuptools>=60.9.0 in /usr/local/lib/python3.10/dist-packages (from ccxt) (67.7.2)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.10/dist-packages (from ccxt) (2022.12.7)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from ccxt) (2.27.1)
# Requirement already satisfied: cryptography>=2.6.1 in /usr/local/lib/python3.10/dist-packages (from ccxt) (40.0.2)
# Requirement already satisfied: aiohttp>=3.8 in /usr/local/lib/python3.10/dist-packages (from ccxt) (3.8.4)
# Requirement already satisfied: aiodns>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from ccxt) (3.0.0)
# Requirement already satisfied: yarl>=1.7.2 in /usr/local/lib/python3.10/dist-packages (from ccxt) (1.9.2)
# Requirement already satisfied: pycares>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from aiodns>=1.1.1->ccxt) (4.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8->ccxt) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8->ccxt) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8->ccxt) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8->ccxt) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8->ccxt) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8->ccxt) (1.3.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.6.1->ccxt) (1.15.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->ccxt) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->ccxt) (3.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt) (2.21)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tabpfn in /usr/local/lib/python3.10/dist-packages (0.1.9)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from tabpfn) (1.22.4)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from tabpfn) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from tabpfn) (2.27.1)
# Requirement already satisfied: scikit-learn>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from tabpfn) (1.2.2)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from tabpfn) (2.0.1+cu118)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->tabpfn) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->tabpfn) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->tabpfn) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->tabpfn) (3.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.2->tabpfn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.2->tabpfn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.2->tabpfn) (3.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->tabpfn) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->tabpfn) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->tabpfn) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->tabpfn) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->tabpfn) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->tabpfn) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.9.0->tabpfn) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.9.0->tabpfn) (16.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9.0->tabpfn) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9.0->tabpfn) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas-ta in /usr/local/lib/python3.10/dist-packages (0.3.14b0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandas-ta) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->pandas-ta) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (3.2.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.11.1)
# Requirement already satisfied: cmaes>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from optuna) (0.9.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)

# %%
import numpy as np 
import pandas as pd 
import json 
import ccxt 
from tqdm import tqdm 
from xgboost import XGBClassifier 
import json
from tabpfn import TabPFNClassifier 
import seaborn as sns
import pandas_ta as ta
from sklearn.utils.class_weight import compute_class_weight
import optuna
from sklearn.metrics import accuracy_score

# %%
with open("/content/BTC_USDT-4h_20230531.json") as f: 
  d = json.load(f) 

chart_df = pd.DataFrame(d) 
chart_df = chart_df.rename(columns={0:"timestamp", 
                                    1:"open",
                                    2:"high",
                                    3:"low",
                                    4:"close",
                                    5:"volume"})  


def process(df):
  binance = ccxt.binance() 
  dates = df["timestamp"].values 
  timestamp = [] 
  for i in range(len(dates)):
    date_string = binance.iso8601(int(dates[i])) 
    date_string = date_string[:10] + " " + date_string[11:-5] 
    timestamp.append(date_string) 
  df["datetime"] = timestamp 
  df = df.drop(columns={"timestamp"}) 
  return df

chart_df = process(chart_df) 

hours, days, months = [], [], [] 
for dt in tqdm(chart_df["datetime"].values):
  dtobj = pd.to_datetime(dt) 
  hours.append(dtobj.hour) 
  days.append(dtobj.day) 
  months.append(dtobj.month) 

chart_df["months"] = months
chart_df["days"] = days 
chart_df["hours"] = hours 
chart_df.set_index(pd.DatetimeIndex(chart_df["datetime"]), inplace=True) 
chart_df.drop(columns={"datetime"}, inplace=True)
# Out:
# 100%|██████████| 12662/12662 [00:00<00:00, 14811.30it/s]

# %%
def preprocess(df, threshold = 0.0075): 
  targets = [] 
  high = chart_df["high"].values 
  low = chart_df["low"].values 
  close = chart_df["close"].values 
  for i in range(close.shape[0]-1): 
    high_vol = (high[i+1] - close[i]) / close[i] 
    low_vol = (low[i+1] - close[i]) / close[i] 
    if high_vol >= threshold:
      targets.append(0) 
    elif low_vol <= -threshold:
      targets.append(1)
    else:
      targets.append(2) 
  targets.append(None)
  df["targets"] = targets 

  columns_to_drop = ["open", "high", "low", "close", "volume"] 
  
  df["bop"] = chart_df.ta.bop(lookahead=False) 
  df["obv"] = chart_df.ta.obv(lookahead=False)
  df["ebsw"] = chart_df.ta.ebsw(lookahead=False) 
  df["cmf"] = chart_df.ta.cmf(lookahead=False)
  df["rsi/100"] = chart_df.ta.rsi(lookahead=False) / 100   
  df["linreg"] = chart_df.ta.linreg(lookahead=False) 
  df["linreg_ratio"] = df["linreg"] / df["close"] 
  columns_to_drop.append("linreg")
  
  windows = [5, 10, 20, 60, 120] 
  for window in windows: 
    df[f"close_ma{window}"] = df["close"].rolling(window).mean() 
    df[f"volume_ma{window}"] = df["volume"].rolling(window).mean() 
    df[f"close_ma{window}_ratio"] = (df["close"] - df[f"close_ma{window}"]) / df[f"close_ma{window}"] 
    df[f"volume_ma{window}_ratio"] = (df["volume"] - df[f"volume_ma{window}"]) / df[f"volume_ma{window}"] 
    columns_to_drop.append(f"close_ma{window}")
    columns_to_drop.append(f"volume_ma{window}")

  df["open_lastclose_ratio"] = np.zeros(len(df)) 
  df.loc[1:, "open_lastclose_ratio"] = (df["open"][1:].values - df["close"][:-1].values) / df["close"][:-1].values 
  df["high_close_ratio"] = (df["high"].values - df["close"].values) / df["close"].values 
  df["low_close_ratio"] = (df["low"].values - df["close"].values) / df["close"].values 
  df["close_lastclose_ratio"] = np.zeros(len(df))
  df.loc[1:, "close_lastclose_ratio"] = (df["close"][1:].values - df["close"][:-1].values) / df["close"][:-1].values 
  df["volume_lastvolume_ratio"] = np.zeros(len(df))  
  df.loc[1:, "volume_lastvolume_ratio"] = ((df["volume"][1:].values - df["volume"][:-1].values) / df["volume"][:-1].replace(to_replace=0, method="ffill").replace(to_replace=0, method="bfill").values)
  df.dropna(inplace=True) 
  df.drop(columns=columns_to_drop,inplace=True) 
  return df

# %%
chart_df = preprocess(chart_df)
# Out:
# <ipython-input-3-900b648397dd>:39: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   df.loc[1:, "open_lastclose_ratio"] = (df["open"][1:].values - df["close"][:-1].values) / df["close"][:-1].values
# <ipython-input-3-900b648397dd>:43: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   df.loc[1:, "close_lastclose_ratio"] = (df["close"][1:].values - df["close"][:-1].values) / df["close"][:-1].values
# <ipython-input-3-900b648397dd>:45: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   df.loc[1:, "volume_lastvolume_ratio"] = ((df["volume"][1:].values - df["volume"][:-1].values) / df["volume"][:-1].replace(to_replace=0, method="ffill").replace(to_replace=0, method="bfill").values)

# %%
train_size = int(0.8 * chart_df.shape[0]) 
val_size = int(0.1 * chart_df.shape[0]) 
train_df = chart_df.iloc[:train_size] 
val_df = chart_df.iloc[train_size:train_size+val_size] 
test_df = chart_df.iloc[train_size+val_size:] 

train_df.shape, val_df.shape, test_df.shape
# Out:
# ((10033, 25), (1254, 25), (1255, 25))

# %%
input_features = [] 
for col in train_df.columns: 
  if col != "targets": 
    input_features.append(col) 

X_train = train_df[input_features].values  
Y_train = train_df["targets"].values  

X_valid = val_df[input_features].values 
Y_valid = val_df["targets"].values 

X_test = test_df[input_features].values 
Y_test = test_df["targets"].values 

X_train.shape, Y_train.shape, X_valid.shape, Y_valid.shape, X_test.shape, Y_test.shape
# Out:
# ((10033, 24), (10033,), (1254, 24), (1254,), (1255, 24), (1255,))

# %%
X_full = np.concatenate([X_train, X_valid], axis=0)
Y_full = np.concatenate([Y_train, Y_valid], axis=0)  

X_full.shape, Y_full.shape
# Out:
# ((11287, 24), (11287,))

# %%
class_weights = compute_class_weight(class_weight="balanced", 
                                     classes=np.unique(Y_train), 
                                     y=np.array(Y_train))

# %%
class_weights
# Out:
# array([0.67236295, 1.12000447, 1.61328188])

# %%
# optuna - will this give better results?  
def objective(trial): 
  param = {
      "tree_method": "gpu_hist", 
      "lambda": trial.suggest_loguniform("lambda", 1e-3, 10), 
      "alpha": trial.suggest_loguniform("alpha", 1e-3, 10), 
      "colsample_bytree": trial.suggest_categorical("colsample_bytree", [0.5, 0.7, 0.9, 1.0]), 
      "subsample": trial.suggest_categorical("subsample", [0.5, 0.7, 0.9, 1.0]), 
      "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5), 
      "n_estimators": trial.suggest_int("n_estimators", 100, 1500), 
      "max_depth": trial.suggest_int("max_depth", 3, 10), 
      "random_state": 42, 
      "min_child_weight": trial.suggest_int("min_child_weight", 3, 10), 
  }
  model = XGBClassifier(**param) 
  model.fit(X_full, Y_full, verbose=False)  
  preds = model.predict(X_test) 
  pred_labels = np.rint(preds) 
  accuracy = accuracy_score(Y_test, pred_labels) 
  return accuracy 

study = optuna.create_study(direction="maximize") 
study.optimize(objective, n_trials=100) 

trial = study.best_trial 

print(trial.value)
print("="*100) 
for key, value in trial.params.items(): 
  print("{}:{}".format(key, value))
# Out:
# [I 2023-05-31 10:21:34,267] A new study created in memory with name: no-name-5bb033fe-8439-438f-9199-d1d7e0187597
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:21:36,087] Trial 0 finished with value: 0.500398406374502 and parameters: {'lambda': 2.332595155691973, 'alpha': 0.6934668663531006, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.16902190768891953, 'n_estimators': 311, 'max_depth': 3, 'min_child_weight': 3}. Best is trial 0 with value: 0.500398406374502.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:21:37,740] Trial 1 finished with value: 0.5282868525896415 and parameters: {'lambda': 0.7079519849189722, 'alpha': 0.001372548282267134, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.031069611778129842, 'n_estimators': 558, 'max_depth': 3, 'min_child_weight': 7}. Best is trial 1 with value: 0.5282868525896415.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:21:38,998] Trial 2 finished with value: 0.5250996015936255 and parameters: {'lambda': 0.021276878199727536, 'alpha': 0.0652061995970093, 'colsample_bytree': 0.9, 'subsample': 0.7, 'learning_rate': 0.03299125415331122, 'n_estimators': 411, 'max_depth': 3, 'min_child_weight': 9}. Best is trial 1 with value: 0.5282868525896415.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:21:45,921] Trial 3 finished with value: 0.5067729083665339 and parameters: {'lambda': 0.8737361873136116, 'alpha': 0.26124142514006515, 'colsample_bytree': 0.9, 'subsample': 1.0, 'learning_rate': 0.01010671200068168, 'n_estimators': 813, 'max_depth': 7, 'min_child_weight': 6}. Best is trial 1 with value: 0.5282868525896415.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:21:49,075] Trial 4 finished with value: 0.4605577689243028 and parameters: {'lambda': 0.0053052303354038256, 'alpha': 1.920905869965867, 'colsample_bytree': 1.0, 'subsample': 0.9, 'learning_rate': 0.18722889705772264, 'n_estimators': 820, 'max_depth': 3, 'min_child_weight': 4}. Best is trial 1 with value: 0.5282868525896415.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:21:51,098] Trial 5 finished with value: 0.5227091633466135 and parameters: {'lambda': 0.0022478241943945775, 'alpha': 0.0035238080249556233, 'colsample_bytree': 1.0, 'subsample': 0.7, 'learning_rate': 0.049070472374207495, 'n_estimators': 657, 'max_depth': 3, 'min_child_weight': 9}. Best is trial 1 with value: 0.5282868525896415.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:22:01,948] Trial 6 finished with value: 0.4709163346613546 and parameters: {'lambda': 1.1578251799870478, 'alpha': 0.597931412131308, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.3669556979847073, 'n_estimators': 1342, 'max_depth': 10, 'min_child_weight': 8}. Best is trial 1 with value: 0.5282868525896415.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:22:06,183] Trial 7 finished with value: 0.47729083665338645 and parameters: {'lambda': 6.104545715085859, 'alpha': 0.04338363346854654, 'colsample_bytree': 0.9, 'subsample': 0.9, 'learning_rate': 0.09109421788666547, 'n_estimators': 803, 'max_depth': 5, 'min_child_weight': 10}. Best is trial 1 with value: 0.5282868525896415.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:22:12,176] Trial 8 finished with value: 0.47410358565737054 and parameters: {'lambda': 3.657536503709541, 'alpha': 0.2223131507835149, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 0.14743720635030252, 'n_estimators': 535, 'max_depth': 9, 'min_child_weight': 5}. Best is trial 1 with value: 0.5282868525896415.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:22:15,186] Trial 9 finished with value: 0.5075697211155379 and parameters: {'lambda': 0.2059174223052256, 'alpha': 9.920839026932262, 'colsample_bytree': 1.0, 'subsample': 0.5, 'learning_rate': 0.12373397072538021, 'n_estimators': 891, 'max_depth': 3, 'min_child_weight': 10}. Best is trial 1 with value: 0.5282868525896415.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:22:16,450] Trial 10 finished with value: 0.5083665338645418 and parameters: {'lambda': 0.13310562065416232, 'alpha': 0.0012396255186668409, 'colsample_bytree': 0.7, 'subsample': 1.0, 'learning_rate': 0.01725018725502117, 'n_estimators': 131, 'max_depth': 6, 'min_child_weight': 7}. Best is trial 1 with value: 0.5282868525896415.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:22:19,034] Trial 11 finished with value: 0.5115537848605578 and parameters: {'lambda': 0.025330397236638, 'alpha': 0.017517890590101098, 'colsample_bytree': 0.9, 'subsample': 0.7, 'learning_rate': 0.035861293109921165, 'n_estimators': 455, 'max_depth': 5, 'min_child_weight': 8}. Best is trial 1 with value: 0.5282868525896415.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:22:20,389] Trial 12 finished with value: 0.5179282868525896 and parameters: {'lambda': 0.036617599113490495, 'alpha': 0.010581719192080303, 'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.02457611088486421, 'n_estimators': 265, 'max_depth': 5, 'min_child_weight': 7}. Best is trial 1 with value: 0.5282868525896415.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:22:24,255] Trial 13 finished with value: 0.5290836653386454 and parameters: {'lambda': 0.36436662154688376, 'alpha': 0.05021447712093114, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.008390918055927383, 'n_estimators': 1006, 'max_depth': 4, 'min_child_weight': 8}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:22:28,749] Trial 14 finished with value: 0.5131474103585657 and parameters: {'lambda': 0.3950315465216117, 'alpha': 0.0018504126161317073, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.005412037564000574, 'n_estimators': 1119, 'max_depth': 4, 'min_child_weight': 6}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:22:37,307] Trial 15 finished with value: 0.5155378486055777 and parameters: {'lambda': 0.45369375923230393, 'alpha': 0.0049168595558051476, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.015188640128578271, 'n_estimators': 1059, 'max_depth': 7, 'min_child_weight': 8}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:22:42,519] Trial 16 finished with value: 0.5131474103585657 and parameters: {'lambda': 7.500540568412652, 'alpha': 0.029676159766043205, 'colsample_bytree': 0.7, 'subsample': 1.0, 'learning_rate': 0.005334655792902192, 'n_estimators': 1356, 'max_depth': 4, 'min_child_weight': 5}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:22:52,620] Trial 17 finished with value: 0.48446215139442234 and parameters: {'lambda': 1.42359396814765, 'alpha': 0.0049507508135111025, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.06679281768752358, 'n_estimators': 1109, 'max_depth': 8, 'min_child_weight': 7}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:22:55,235] Trial 18 finished with value: 0.5131474103585657 and parameters: {'lambda': 0.09158380983691397, 'alpha': 0.010488372650376157, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.009925387839705202, 'n_estimators': 657, 'max_depth': 4, 'min_child_weight': 9}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:22:59,641] Trial 19 finished with value: 0.4940239043824701 and parameters: {'lambda': 0.5576544098221928, 'alpha': 0.0011153428020703087, 'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.05867070077641834, 'n_estimators': 649, 'max_depth': 6, 'min_child_weight': 5}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:23:03,820] Trial 20 finished with value: 0.5235059760956176 and parameters: {'lambda': 2.0251278744769476, 'alpha': 0.0948226283366995, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.021354884831633857, 'n_estimators': 1012, 'max_depth': 4, 'min_child_weight': 6}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:23:05,750] Trial 21 finished with value: 0.5187250996015936 and parameters: {'lambda': 0.27321503040624306, 'alpha': 0.06604759251350555, 'colsample_bytree': 0.9, 'subsample': 0.7, 'learning_rate': 0.033899101841128446, 'n_estimators': 413, 'max_depth': 3, 'min_child_weight': 9}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:23:07,948] Trial 22 finished with value: 0.5163346613545817 and parameters: {'lambda': 0.06665087107425897, 'alpha': 0.02630939189226645, 'colsample_bytree': 0.9, 'subsample': 0.7, 'learning_rate': 0.032311975647383875, 'n_estimators': 491, 'max_depth': 4, 'min_child_weight': 8}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:23:14,457] Trial 23 finished with value: 0.5123505976095617 and parameters: {'lambda': 0.016576452730657464, 'alpha': 0.052112348864976274, 'colsample_bytree': 0.9, 'subsample': 0.7, 'learning_rate': 0.012737318042433448, 'n_estimators': 1215, 'max_depth': 5, 'min_child_weight': 9}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:23:19,262] Trial 24 finished with value: 0.5274900398406375 and parameters: {'lambda': 0.17838263411782945, 'alpha': 0.01302094055483465, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.022524898769412556, 'n_estimators': 1486, 'max_depth': 3, 'min_child_weight': 10}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:23:24,682] Trial 25 finished with value: 0.5266932270916335 and parameters: {'lambda': 0.1565353681493636, 'alpha': 0.01462174171527886, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.008063102642049864, 'n_estimators': 1436, 'max_depth': 4, 'min_child_weight': 10}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:23:33,900] Trial 26 finished with value: 0.49800796812749004 and parameters: {'lambda': 0.7040079607882662, 'alpha': 0.0031673936920431096, 'colsample_bytree': 0.7, 'subsample': 1.0, 'learning_rate': 0.01913493023797207, 'n_estimators': 936, 'max_depth': 6, 'min_child_weight': 7}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:23:38,732] Trial 27 finished with value: 0.5187250996015936 and parameters: {'lambda': 0.3060139747690573, 'alpha': 0.007526462307435714, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.024113991935856584, 'n_estimators': 1247, 'max_depth': 3, 'min_child_weight': 8}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:23:46,275] Trial 28 finished with value: 0.5195219123505976 and parameters: {'lambda': 0.8432131258731199, 'alpha': 0.0021262681695561137, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01338475673012545, 'n_estimators': 579, 'max_depth': 5, 'min_child_weight': 10}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:23:52,397] Trial 29 finished with value: 0.5227091633466135 and parameters: {'lambda': 2.7883739236003553, 'alpha': 0.007018336277076918, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.008250429395167992, 'n_estimators': 1444, 'max_depth': 3, 'min_child_weight': 4}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:23:53,635] Trial 30 finished with value: 0.5179282868525896 and parameters: {'lambda': 0.2504660844859765, 'alpha': 0.021382804614950183, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.01635256046777605, 'n_estimators': 298, 'max_depth': 4, 'min_child_weight': 3}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:24:00,091] Trial 31 finished with value: 0.5227091633466135 and parameters: {'lambda': 0.16859938812324118, 'alpha': 0.011541395503980272, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.007383259104758669, 'n_estimators': 1495, 'max_depth': 4, 'min_child_weight': 10}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:24:04,056] Trial 32 finished with value: 0.5258964143426295 and parameters: {'lambda': 0.12159512289440119, 'alpha': 0.01620381126798118, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.01213725423003036, 'n_estimators': 1339, 'max_depth': 3, 'min_child_weight': 10}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:24:08,972] Trial 33 finished with value: 0.5211155378486055 and parameters: {'lambda': 0.47158694469577506, 'alpha': 0.0033466698816596806, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.006972948164742654, 'n_estimators': 1239, 'max_depth': 4, 'min_child_weight': 9}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:24:13,811] Trial 34 finished with value: 0.5266932270916335 and parameters: {'lambda': 0.07417573789128855, 'alpha': 0.03402496547741684, 'colsample_bytree': 1.0, 'subsample': 0.5, 'learning_rate': 0.01007612914617979, 'n_estimators': 1419, 'max_depth': 3, 'min_child_weight': 10}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:24:16,524] Trial 35 finished with value: 0.5091633466135458 and parameters: {'lambda': 0.21645885681218788, 'alpha': 0.10638457040116095, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.009276190284431276, 'n_estimators': 739, 'max_depth': 3, 'min_child_weight': 9}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:24:22,219] Trial 36 finished with value: 0.5099601593625498 and parameters: {'lambda': 1.0302663968119812, 'alpha': 0.01591383329890356, 'colsample_bytree': 0.5, 'subsample': 1.0, 'learning_rate': 0.011816595323197144, 'n_estimators': 1182, 'max_depth': 5, 'min_child_weight': 8}. Best is trial 13 with value: 0.5290836653386454.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:24:27,735] Trial 37 finished with value: 0.5171314741035856 and parameters: {'lambda': 0.6537286353563785, 'alpha': 0.0056865179570619526, 'colsample_bytree': 1.0, 'subsample': 0.9, 'learning_rate': 0.006570409339854243, 'n_estimators': 1311, 'max_depth': 4, 'min_child_weight': 9}. Best is trial 13 with value: 0.5290836653386454.
# ...
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:28:29,367] Trial 87 finished with value: 0.4892430278884462 and parameters: {'lambda': 0.39536335023202807, 'alpha': 0.030606976747953287, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.0390570614369472, 'n_estimators': 1410, 'max_depth': 8, 'min_child_weight': 10}. Best is trial 85 with value: 0.5322709163346614.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:28:30,962] Trial 88 finished with value: 0.5131474103585657 and parameters: {'lambda': 0.7290007545580501, 'alpha': 0.037937353395483854, 'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.058144760182792674, 'n_estimators': 366, 'max_depth': 4, 'min_child_weight': 10}. Best is trial 85 with value: 0.5322709163346614.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:28:35,025] Trial 89 finished with value: 0.5266932270916335 and parameters: {'lambda': 0.26781141764834565, 'alpha': 0.01953457899435396, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.01263646923627445, 'n_estimators': 681, 'max_depth': 5, 'min_child_weight': 9}. Best is trial 85 with value: 0.5322709163346614.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:28:38,446] Trial 90 finished with value: 0.5179282868525896 and parameters: {'lambda': 0.2782138530057973, 'alpha': 0.021834739577722143, 'colsample_bytree': 1.0, 'subsample': 0.7, 'learning_rate': 0.013285566955647404, 'n_estimators': 688, 'max_depth': 5, 'min_child_weight': 9}. Best is trial 85 with value: 0.5322709163346614.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:28:41,568] Trial 91 finished with value: 0.5211155378486055 and parameters: {'lambda': 0.2207843394501641, 'alpha': 0.014375971856015858, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.00907805754778872, 'n_estimators': 612, 'max_depth': 5, 'min_child_weight': 8}. Best is trial 85 with value: 0.5322709163346614.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:28:44,716] Trial 92 finished with value: 0.5266932270916335 and parameters: {'lambda': 0.1728312319986292, 'alpha': 0.017574469480416268, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.011988089713232243, 'n_estimators': 807, 'max_depth': 4, 'min_child_weight': 9}. Best is trial 85 with value: 0.5322709163346614.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:28:48,627] Trial 93 finished with value: 0.5298804780876494 and parameters: {'lambda': 0.1530326123871565, 'alpha': 0.01814364574137143, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.010426389780043323, 'n_estimators': 852, 'max_depth': 4, 'min_child_weight': 8}. Best is trial 85 with value: 0.5322709163346614.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:28:53,809] Trial 94 finished with value: 0.5163346613545817 and parameters: {'lambda': 0.31132374945522856, 'alpha': 0.0657011271556967, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.010200973866348639, 'n_estimators': 778, 'max_depth': 6, 'min_child_weight': 7}. Best is trial 85 with value: 0.5322709163346614.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:28:58,308] Trial 95 finished with value: 0.5179282868525896 and parameters: {'lambda': 0.44566267218687616, 'alpha': 0.010327425733518346, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.014951680529148968, 'n_estimators': 921, 'max_depth': 5, 'min_child_weight': 8}. Best is trial 85 with value: 0.5322709163346614.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:29:02,130] Trial 96 finished with value: 0.5099601593625498 and parameters: {'lambda': 0.14960522553109373, 'alpha': 0.019102249924710248, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.007880984572050736, 'n_estimators': 863, 'max_depth': 4, 'min_child_weight': 8}. Best is trial 85 with value: 0.5322709163346614.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:29:04,496] Trial 97 finished with value: 0.5115537848605578 and parameters: {'lambda': 0.22378484146613467, 'alpha': 0.03694666690805117, 'colsample_bytree': 0.7, 'subsample': 1.0, 'learning_rate': 0.006026987930536901, 'n_estimators': 506, 'max_depth': 4, 'min_child_weight': 9}. Best is trial 85 with value: 0.5322709163346614.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:29:07,560] Trial 98 finished with value: 0.5290836653386454 and parameters: {'lambda': 0.5613872723495231, 'alpha': 0.08730776890493089, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.013690958612568567, 'n_estimators': 778, 'max_depth': 4, 'min_child_weight': 7}. Best is trial 85 with value: 0.5322709163346614.
# <ipython-input-10-8392f8f90cee>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "lambda": trial.suggest_loguniform("lambda", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "alpha": trial.suggest_loguniform("alpha", 1e-3, 10),
# <ipython-input-10-8392f8f90cee>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.5),
# [I 2023-05-31 10:29:11,610] Trial 99 finished with value: 0.5266932270916335 and parameters: {'lambda': 0.5797626365613995, 'alpha': 0.08672832156309856, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.010402340982185149, 'n_estimators': 1037, 'max_depth': 4, 'min_child_weight': 7}. Best is trial 85 with value: 0.5322709163346614.
# 0.5322709163346614
# ====================================================================================================
# lambda:0.41612353749453695
# alpha:0.03172778795858678
# colsample_bytree:0.9
# subsample:0.7
# learning_rate:0.03875879673183694
# n_estimators:307
# max_depth:4
# min_child_weight:9

# %%
trial.params
# Out:
# {'lambda': 0.41612353749453695,
#  'alpha': 0.03172778795858678,
#  'colsample_bytree': 0.9,
#  'subsample': 0.7,
#  'learning_rate': 0.03875879673183694,
#  'n_estimators': 307,
#  'max_depth': 4,
#  'min_child_weight': 9}

# %%
print("done!")
# Out:
# done!

# %%
clf = XGBClassifier(**trial.params, tree_method="gpu_hist")  

clf.fit(X_full, Y_full, verbose=100)
# Out:
# XGBClassifier(alpha=0.03172778795858678, base_score=None, booster=None,
#               callbacks=None, colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, lambda=0.41612353749453695,
#               learning_rate=0.03875879673183694, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=9, missing=nan, monotone_constraints=None,
#               n_estimators=307, n_jobs=None, num_parallel_tree=None, ...)

# %%
Y_pred = clf.predict(X_test) 
cnt = 0 
for i in range(len(Y_pred)): 
  if Y_pred[i] == Y_test[i]: 
    cnt += 1 
  
cnt / len(Y_pred) * 100
# Out:
# 52.589641434262944

# %%
Y_pred
# Out:
# array([2, 2, 2, ..., 1, 1, 0])
